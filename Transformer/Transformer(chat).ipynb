# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunicecream/Natural-Language-Processing-NLP-/blob/main/7_13_transformer(chat).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.1 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96

# %%
# -*- coding: utf-8 -*-
"""7-13.transformer(chat).ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1pnSh26gOExNccGZRzN7MkS1i0DPrElt3
"""

# Commented out IPython magic to ensure Python compatibility.
# Transformer ChatBot : 채팅 모듈
# 참고 : https://github.com/suyash/transformer
#
# 2020.06.07 : 조성현 (blog.naver.com/chunjein)
# ---------------------------------------------
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
import tensorflow.keras.backend as K
import sentencepiece as spm
import pickle
import numpy as np
# %cd '/content/drive/MyDrive/머신러닝/Transformer'
from transformer import Transformer
# Out:
# /content/drive/MyDrive/머신러닝/Transformer

# %%
# Commented out IPython magic to ensure Python compatibility.
# %cd '/content/drive/My Drive/Colab Notebooks'

MAX_LEN = 15
MODEL_PATH = '/content/drive/MyDrive/머신러닝/Transformer/transformer_model.h5'
SPM_MODEL = "/content/drive/MyDrive/머신러닝/seq2seq/chatbot_model.model"

sp = spm.SentencePieceProcessor()
sp.Load(SPM_MODEL)
# Out:
# True

# %%
# Sub-word 사전 읽어온다.
with open('/content/drive/MyDrive/머신러닝/seq2seq/chatbot_voc.pkl', 'rb') as f:
    word2idx,  idx2word = pickle.load(f)

# %%
K.clear_session()
src = Input((None, ), dtype="int32", name="src")
tar = Input((None, ), dtype="int32", name="tar")

logits, enc_enc_attention, dec_dec_attention, enc_dec_attention = Transformer(
    num_layers=4,
    d_model=128,
    num_heads=8,
    d_ff=512,
    input_vocab_size=len(word2idx) + 2,
    target_vocab_size=len(word2idx) + 2,
    dropout_rate=0.1)(src, tar)

model = Model(inputs=[src, tar], outputs=logits)
model.load_weights(MODEL_PATH)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# src (InputLayer)                [(None, None)]       0
# __________________________________________________________________________________________________
# transformer/encoder/embedding ( (None, None, 128)    1152256     src[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, None, 128)    0           transformer/encoder/embedding[0][
# __________________________________________________________________________________________________
# tf.compat.v1.shape_1 (TFOpLambd (3,)                 0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli ()                   0           tf.compat.v1.shape_1[0][0]
# __________________________________________________________________________________________________
# tf.range (TFOpLambda)           (None,)              0           tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 1)            0           tf.range[0][0]
# __________________________________________________________________________________________________
# tf.cast_2 (TFOpLambda)          (None, 1)            0           tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 128)          0           tf.cast_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 64)           0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_6 (Sli (None, 64)           0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.sin (TFOpLambda)        (None, 64)           0           tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# tf.math.cos (TFOpLambda)        (None, 64)           0           tf.__operators__.getitem_6[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 128)          0           tf.math.sin[0][0]
#                                                                  tf.math.cos[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_7 (Sli (1, None, 128)       0           tf.concat[0][0]
# __________________________________________________________________________________________________
# tf.cast_3 (TFOpLambda)          (1, None, 128)       0           tf.__operators__.getitem_7[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/add (Add)   (None, None, 128)    0           tf.math.multiply[0][0]
#                                                                  tf.cast_3[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/add[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/add[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_2 (TFOpLambd (4,)                 0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_8 (Sli ()                   0           tf.compat.v1.shape_2[0][0]
# __________________________________________________________________________________________________
# tf.math.equal (TFOpLambda)      (None, None)         0           src[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.cast_4 (TFOpLambda)          ()                   0           tf.__operators__.getitem_8[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            (None, None)         0           tf.math.equal[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul (TFOpLambda)   (None, 8, None, None 0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.math.sqrt (TFOpLambda)       ()                   0           tf.cast_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 1, 1, None)   0           tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    (None, 8, None, None 0           tf.linalg.matmul[0][0]
#                                                                  tf.math.sqrt[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 1, 1, None)   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/add[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 8, None, None 0           tf.math.truediv[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.nn.softmax (TFOpLambda)      (None, 8, None, None 0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.linalg.matmul_1 (TFOpLambda) (None, 8, None, 16)  0           tf.nn.softmax[0][0]
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           tf.linalg.matmul_1[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/add[0][0]
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    256         transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 512)    66048       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    65664       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    256         transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.compat.v1.shape_3 (TFOpLambd (4,)                 0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_9 (Sli ()                   0           tf.compat.v1.shape_3[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.cast_5 (TFOpLambda)          ()                   0           tf.__operators__.getitem_9[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_2 (TFOpLambda) (None, 8, None, None 0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.math.sqrt_1 (TFOpLambda)     ()                   0           tf.cast_5[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_1 (TFOpLambda)  (None, 8, None, None 0           tf.linalg.matmul_2[0][0]
#                                                                  tf.math.sqrt_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 1, 1, None)   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 8, None, None 0           tf.math.truediv_1[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.nn.softmax_1 (TFOpLambda)    (None, 8, None, None 0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.linalg.matmul_3 (TFOpLambda) (None, 8, None, 16)  0           tf.nn.softmax_1[0][0]
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           tf.linalg.matmul_3[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    256         transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 512)    66048       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    65664       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    256         transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.compat.v1.shape_4 (TFOpLambd (4,)                 0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_10 (Sl ()                   0           tf.compat.v1.shape_4[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.cast_6 (TFOpLambda)          ()                   0           tf.__operators__.getitem_10[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_4 (TFOpLambda) (None, 8, None, None 0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.math.sqrt_2 (TFOpLambda)     ()                   0           tf.cast_6[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_2 (TFOpLambda)  (None, 8, None, None 0           tf.linalg.matmul_4[0][0]
#                                                                  tf.math.sqrt_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 1, 1, None)   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 8, None, None 0           tf.math.truediv_2[0][0]
#                                                                  tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.nn.softmax_2 (TFOpLambda)    (None, 8, None, None 0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.linalg.matmul_5 (TFOpLambda) (None, 8, None, 16)  0           tf.nn.softmax_2[0][0]
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           tf.linalg.matmul_5[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tar (InputLayer)                [(None, None)]       0
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/embedding ( (None, None, 128)    1152256     tar[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    256         transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, None, 128)    0           transformer/decoder/embedding[0][
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 512)    66048       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.compat.v1.shape_6 (TFOpLambd (3,)                 0           tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    65664       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_12 (Sl ()                   0           tf.compat.v1.shape_6[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.range_1 (TFOpLambda)         (None,)              0           tf.__operators__.getitem_12[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_13 (Sl (None, 1)            0           tf.range_1[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    256         transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.cast_8 (TFOpLambda)          (None, 1)            0           tf.__operators__.getitem_13[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 128)          0           tf.cast_8[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_14 (Sl (None, 64)           0           tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_15 (Sl (None, 64)           0           tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.math.sin_1 (TFOpLambda)      (None, 64)           0           tf.__operators__.getitem_14[0][0]
# __________________________________________________________________________________________________
# tf.math.cos_1 (TFOpLambda)      (None, 64)           0           tf.__operators__.getitem_15[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.compat.v1.shape_5 (TFOpLambd (4,)                 0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 128)          0           tf.math.sin_1[0][0]
#                                                                  tf.math.cos_1[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_11 (Sl ()                   0           tf.compat.v1.shape_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_16 (Sl (1, None, 128)       0           tf.concat_1[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.cast_7 (TFOpLambda)          ()                   0           tf.__operators__.getitem_11[0][0]
# __________________________________________________________________________________________________
# tf.cast_9 (TFOpLambda)          (1, None, 128)       0           tf.__operators__.getitem_16[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_6 (TFOpLambda) (None, 8, None, None 0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.math.sqrt_3 (TFOpLambda)     ()                   0           tf.cast_7[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/add (Add)   (None, None, 128)    0           tf.math.multiply_6[0][0]
#                                                                  tf.cast_9[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_3 (TFOpLambda)  (None, 8, None, None 0           tf.linalg.matmul_6[0][0]
#                                                                  tf.math.sqrt_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 1, 1, None)   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/add[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 8, None, None 0           tf.math.truediv_3[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.compat.v1.shape (TFOpLambda) (2,)                 0           tar[0][0]
# __________________________________________________________________________________________________
# tf.nn.softmax_3 (TFOpLambda)    (None, 8, None, None 0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, 8, None, 16)  0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli ()                   0           tf.compat.v1.shape[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_7 (TFOpLambda) (None, 8, None, 16)  0           tf.nn.softmax_3[0][0]
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/add[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_7 (TFOpLambd (4,)                 0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.ones (TFOpLambda)            (None, None)         0           tf.__operators__.getitem_1[0][0]
#                                                                  tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.math.equal_1 (TFOpLambda)    (None, None)         0           tar[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 8, 16)  0           tf.linalg.matmul_7[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_17 (Sl ()                   0           tf.compat.v1.shape_7[0][0]
# __________________________________________________________________________________________________
# tf.linalg.band_part (TFOpLambda (None, None)         0           tf.ones[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          (None, None)         0           tf.math.equal_1[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.cast_10 (TFOpLambda)         ()                   0           tf.__operators__.getitem_17[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, None)         0           tf.linalg.band_part[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli (None, 1, 1, None)   0           tf.cast_1[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.linalg.matmul_8 (TFOpLambda) (None, 8, None, None 0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.math.sqrt_4 (TFOpLambda)     ()                   0           tf.cast_10[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum (TFOpLambda)    (None, 1, None, None 0           tf.math.subtract[0][0]
#                                                                  tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.math.truediv_4 (TFOpLambda)  (None, 8, None, None 0           tf.linalg.matmul_8[0][0]
#                                                                  tf.math.sqrt_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 1, None, None 0           tf.math.maximum[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/add[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 8, None, None 0           tf.math.truediv_4[0][0]
#                                                                  tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    256         transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.nn.softmax_4 (TFOpLambda)    (None, 8, None, None 0           tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 512)    66048       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.linalg.matmul_9 (TFOpLambda) (None, 8, None, 16)  0           tf.nn.softmax_4[0][0]
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    65664       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           tf.linalg.matmul_9[0][0]
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    0           transformer/encoder/encoder_layer
#                                                                  transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/encoder/encoder_lay (None, None, 128)    256         transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/add[0][0]
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    256         transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.compat.v1.shape_8 (TFOpLambd (4,)                 0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_18 (Sl ()                   0           tf.compat.v1.shape_8[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.cast_11 (TFOpLambda)         ()                   0           tf.__operators__.getitem_18[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_10 (TFOpLambda (None, 8, None, None 0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.math.sqrt_5 (TFOpLambda)     ()                   0           tf.cast_11[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_5 (TFOpLambda)  (None, 8, None, None 0           tf.linalg.matmul_10[0][0]
#                                                                  tf.math.sqrt_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None, 1, 1, None)   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 8, None, None 0           tf.math.truediv_5[0][0]
#                                                                  tf.math.multiply_9[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.nn.softmax_5 (TFOpLambda)    (None, 8, None, None 0           tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.linalg.matmul_11 (TFOpLambda (None, 8, None, 16)  0           tf.nn.softmax_5[0][0]
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           tf.linalg.matmul_11[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    256         transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 512)    66048       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    65664       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# ...
# tf.__operators__.add_9 (TFOpLam (None, 8, None, None 0           tf.math.truediv_9[0][0]
#                                                                  tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.nn.softmax_9 (TFOpLambda)    (None, 8, None, None 0           tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.linalg.matmul_19 (TFOpLambda (None, 8, None, 16)  0           tf.nn.softmax_9[0][0]
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           tf.linalg.matmul_19[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    256         transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 512)    66048       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    65664       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    256         transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.compat.v1.shape_13 (TFOpLamb (4,)                 0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_23 (Sl ()                   0           tf.compat.v1.shape_13[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.cast_16 (TFOpLambda)         ()                   0           tf.__operators__.getitem_23[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_20 (TFOpLambda (None, 8, None, None 0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.math.sqrt_10 (TFOpLambda)    ()                   0           tf.cast_16[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_10 (TFOpLambda) (None, 8, None, None 0           tf.linalg.matmul_20[0][0]
#                                                                  tf.math.sqrt_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_14 (TFOpLambda (None, 1, None, None 0           tf.math.maximum[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 8, None, None 0           tf.math.truediv_10[0][0]
#                                                                  tf.math.multiply_14[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.nn.softmax_10 (TFOpLambda)   (None, 8, None, None 0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.linalg.matmul_21 (TFOpLambda (None, 8, None, 16)  0           tf.nn.softmax_10[0][0]
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           tf.linalg.matmul_21[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    256         transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.compat.v1.shape_14 (TFOpLamb (4,)                 0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.getitem_24 (Sl ()                   0           tf.compat.v1.shape_14[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.cast_17 (TFOpLambda)         ()                   0           tf.__operators__.getitem_24[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_22 (TFOpLambda (None, 8, None, None 0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.math.sqrt_11 (TFOpLambda)    ()                   0           tf.cast_17[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_11 (TFOpLambda) (None, 8, None, None 0           tf.linalg.matmul_22[0][0]
#                                                                  tf.math.sqrt_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_15 (TFOpLambda (None, 1, 1, None)   0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/encoder/encoder_layer
# __________________________________________________________________________________________________
# tf.__operators__.add_11 (TFOpLa (None, 8, None, None 0           tf.math.truediv_11[0][0]
#                                                                  tf.math.multiply_15[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.nn.softmax_11 (TFOpLambda)   (None, 8, None, None 0           tf.__operators__.add_11[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, 8, None, 16)  0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# tf.linalg.matmul_23 (TFOpLambda (None, 8, None, 16)  0           tf.nn.softmax_11[0][0]
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 8, 16)  0           tf.linalg.matmul_23[0][0]
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    16512       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    256         transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 512)    66048       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    65664       transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    0           transformer/decoder/decoder_layer
#                                                                  transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/decoder/decoder_lay (None, None, 128)    256         transformer/decoder/decoder_layer
# __________________________________________________________________________________________________
# transformer/dense (Dense)       (None, None, 9002)   1161258     transformer/decoder/decoder_layer
# ==================================================================================================
# Total params: 5,317,162
# Trainable params: 5,317,162
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Question을 입력받아 Answer를 생성한다.
def genAnswer(question):
    question = question[np.newaxis, :]
    target = np.array(sp.bos_id()).reshape(1, 1)

    answer = []
    for i in range(MAX_LEN):
        preds = model.predict_on_batch([question, target])
        
        # 디코더의 출력은 vocabulary에 대응되는 one-hot이다.
        # argmax로 해당 단어를 채택한다.
        nextWord = np.argmax(preds[:, -1:, :], axis=-1)
        
        # 예상 단어가 <EOS>이거나 <PAD>이면 더 이상 예상할 게 없다.
        if nextWord == sp.eos_id() or nextWord == sp.pad_id():
            break

        # 다음 예상 단어인 디코더의 출력을 answer에 추가한다.
        answer.append(idx2word[nextWord[0][0]])
        
        # 다음 target을 준비한다.
        target = np.concatenate([target, nextWord], axis = -1)
    
    return sp.decode_pieces(answer)

# %%
# Chatting
def chatting(n=100):   
    for i in range(n):
        question = input('Q : ')
        
        if  question == 'quit':
            break
        
        q_idx = []
        for x in sp.encode_as_pieces(question):
            if x in word2idx:
                q_idx.append(word2idx[x])
            else:
                q_idx.append(sp.unk_id())   # out-of-vocabulary (OOV)
        
        # <PAD>를 삽입한다.
        if len(q_idx) < MAX_LEN:
            q_idx.extend([sp.pad_id()] * (MAX_LEN - len(q_idx)))
        else:
            q_idx = q_idx[0:MAX_LEN]

        answer = genAnswer(np.array(q_idx))
        print('A :', answer)

# %%
####### Chatting 시작 #######
print("\nTransformer ChatBot (ver. 1.0)")
print("Chatting 모듈을 로드하고 있습니다 ...")

# 처음 1회는 시간이 걸리기 때문에 dummy question을 입력한다.
answer = genAnswer(np.zeros(MAX_LEN))
print("ChatBot이 준비 됐습니다.\n")

chatting(100)
# Out:
# Transformer ChatBot (ver. 1.0)
# Chatting 모듈을 로드하고 있습니다 ...
# ChatBot이 준비 됐습니다.
#
# Q : 신혼여행 어디로 갈까
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3eaded5a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# A : 못 가본 곳으로 가보세요
# Q : 반 배정 잘 될까'
# A : 잘 되길 바랍니다
# Q : quit

# %%
# train data:
# [('이별 후 1년 그리고 선물', '이별하신게 맞나요'),
#  ('허기져', '챙겨 드세요'),
#  ('맥주 소주 어떤거 마실까', '소맥이요'),
#  ('교양 수업 재밌어', '저도 듣고 싶어요'),
#  ('권태기 이별', '극복하거나 이별하거나 둘 중 하나죠'),
#  ('읽씹은 아프네', '상대방에 대한 예의가 없네요'),
#  ('신혼여행 어디로 갈까', '못 가본 곳으로 가보세요'),
#  ('반 배정 잘 될까', '잘 되길 바랍니다'),
#  ('친구가 다 떠나서 내가 못났나 싶어', '지난 인연에 연연해하지 마세요'),
#  ('뒤돌아 보지 말고 나가야 하는데', '살짝 뒤돌아봐도 괜찮아요')]

# test data:
# [('소오름 쫙', '좋은 일이길 바랍니다'),
#  ('고백은 어떻게 하는거야', '솔직한 마음으로 다가가는 거죠'),
#  ('참 잘낫네', '진정하셔요'),
#  ('늘 빡빡하게 살기 힘드네', '여유가 생기길 바랍니다'),
#  ('집까지 데려다줬는데 호감 그냥 매너', '호감이 있을 수도 있어요 그렇지만 조금 더 상황을 지켜보세요'),
#  ('짝녀가 연락 안 되고 있는데 자나', '자고 있을지도 모르겠어요'),
#  ('마음도 춥고 날씨도 춥고', '마음 감기 조심하세요'),
#  ('죽었던 연애세포가 살아나는 것 같아', '좋은 소식이네요'),
#  ('겨울에는 온천이지', '몸은 뜨겁고 머리는 차갑게'),
#  ('소개팅 하고싶다', '친구한테 부탁해보세요')]
